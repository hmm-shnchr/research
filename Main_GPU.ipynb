# %%
##Import some modules used for this notebook.
from get_save_directory import get_save_dir
from make_dataset import make_dataset
from normalization import Normalization
from make_train_test_dataset import MakeTrainTestDataset
from artificial_neural_network_gpu import ArtificialNeuralNetwork
from interpolate import interpolate
from relative_error import relative_error
from about_directory import about_dir
import os, sys, shutil
import numpy
import cupy as np
import copy as cp
import pickle

# %%
##Print a dir_list which is a list of ectracted parameters.
##The parameters are made by ./parameter/MakePickleOfParam.ipynb.
dir_list = numpy.loadtxt("param_list.txt", dtype = "str")
for i in range(len(dir_list)):
    print("{}. {}".format(i, dir_list[i]))
# Out:
# 0. param_1e+6_1e+18_ScaleFactor_ID_pid_Mvir_Rvir_x_vx_MW039_MW038.pickle
# 1. param_1e+7_1e+18_ScaleFactor_ID_pid_Mvir_Rvir_x_vx_MW039_MW038.pickle
# 2. param_1e+6_1e+18_ScaleFactor_ID_pid_Mvir_Rvir_x_vx_MW039_MW038_MW035.pickle
# 3. param_1e+7_1e+18_ScaleFactor_ID_pid_Mvir_Rvir_x_vx_MW039_MW038_MW035.pickle
# 4. param_1e+6_1e+18_ScaleFactor_ID_pid_Mvir_Rvir_x_vx_MW039_MW038_MW035_MW034_MW033_MW032.pickle
# 5. param_1e+7_1e+18_ScaleFactor_ID_pid_Mvir_Rvir_x_vx_MW039_MW038_MW035_MW034_MW033_MW032.pickle

# %%
##Input index-number of param_list.txt in dir_num to select it.
##Load the parameters of host-halo and sub-halo.
dir_num = int(input("\nSelect index>> "))
with open("parameters/" + dir_list[dir_num], mode = "rb") as f:
    param = pickle.load(f)
with open("parameters/host_" + dir_list[dir_num], mode = "rb") as f:
    host_param = pickle.load(f)
# Out:
# Select index>> 3

# %%
##The list of used parameters and host-halo.
param_list = list(param.keys())
mainbranch_list = list(param[param_list[0]].keys())
print(param_list)
print(mainbranch_list)
# Out:
# ['ScaleFactor', 'ID', 'pid', 'Mvir', 'Rvir', 'x', 'vx']
# ['mainbranch_MW039.csv', 'mainbranch_MW038.csv', 'mainbranch_MW035.csv']

# %%
##Get zacc of each sub-halo as acc_sf(Data type is dictionary).
##The zacc is a time when ID of host-halo and pid of sub-halo match.
acc_sf = {}
for m_key in mainbranch_list:
    acc_sf[m_key] = []
    for idx, parameter in enumerate(param["pid"][m_key]):
        for i in range(parameter.size):
            host_i = host_param["ID"][m_key].size - parameter.size + i
            if host_param["ID"][m_key][host_i] == parameter[i]:
                acc_sf[m_key].append(i)
                break
            elif i == parameter.size-1:
                acc_sf[m_key].append(-1)

# %%
##Describe variables of learning-parameter of a DeepLearningModel in LearnParam.
class LearnParam:
    def __init__(self):
        self.eps = 1.0  ##Prevent devision by zero like 1 / (0 + eps).
        self.bias = True ##If This bias is True, add normalized dataset to bias.
        self.hidden = [1000]*10  ##Defines number of hidden layers and neurons in each layers.
        self.batchsize_denominator = 200  ##Defines a size of mini-batch as size(train-dataset) /  batch_denominator.
        self.learning_rate = "1e-3"  ##Learning rate of Back propagation.
        self.optimizer = "Adam"  ##Optimizer of the DeepLearningModel.
        self.batch_normalization = True  ##Whether to use BatchNormalization or not.
        self.loss_func = "MSE_RE"  ##Loss function of a DeepLearning model.
        self.activation_func = "relu"  ##Activation function of the hidden layers.
        self.weight_init = "he"  ##Condition for initializing weight of the hidden layers.
        self.lastlayer_identity = True
        self.epoch = 100  ##Training epoch.
        self.input_size = 2  ##Size of input-dataset(axis == 1)
        self.output_size = 3  ##Size of output-dataset(axis == 1)
        self.param_kind = "x"  ##Learning parameter.
        self.train_ratio = 0.7  ##Percentage of training-dataset to all-dataset.
        self.normalize_format = "Normalization"  ##Selects a format of dataset normalization in None, Normalization, Standardization.
        self.extract_dataset = "After_acc"  ##Selects a condition of dataset.
        ##All is overall, Before/After_acc is in part of before/after accretion, All(_not)_acc is overall of (not)accreted sub-halo.
        self.learn_num = 2  ##Distinguishes the directories where training results are saved.
        self.save_fig_type = ".png"  ##Format of the saved figures.

# %%
LP = LearnParam()
save_dir = get_save_dir(LP)
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
    print("Make a directory {}.".format(save_dir))
else:
    print("Warning!\nThis directory \"{0}\" is an existing directory.\nIt will be overwritten.".format(save_dir))
# Out:
# Make a directory 2in_3out/x_10layers_1000neurons_BatchNorm_MSE_RE_1e-3lr_100epoch_Normalization_After_acc_2/.

# %%
dataset = make_dataset(mainbranch_list, LP.param_kind, host_param, param, LP.extract_dataset, acc_sf)
Norm = Normalization(mainbranch_list, LP.normalize_format, LP.bias, LP.eps)
dataset_normed = Norm.run(dataset)
MTTD = MakeTrainTestDataset(mainbranch_list)
train, test = MTTD.split(cp.deepcopy(dataset_normed), LP.train_ratio)
# Out:
# m_list : ['mainbranch_MW039.csv', 'mainbranch_MW038.csv', 'mainbranch_MW035.csv']
# norm_format : Normalization
# bias : True
# eps : 1.0

# %%
ANN = ArtificialNeuralNetwork(LP.input_size, LP.hidden, LP.activation_func, LP.weight_init, LP.batch_normalization, LP.output_size, LP.lastlayer_identity, LP.loss_func)

# %%
# %%timeit -n 1 -r 1
ANN.learning(cp.deepcopy(train), cp.deepcopy(test), LP.optimizer, LP.learning_rate, LP.batchsize_denominator, LP.epoch, mainbranch_list)
# Out:
# Make train/test dataset.
# 10min 24s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %%
ANN.plot_figures(save_dir, LP.save_fig_type)

# %%
interpolate_methods = ["origin", "ann", "linear", "cubic"]
interp_normed, interp_inv = {}, {}
for ip_key in interpolate_methods:
    pred_normed, pred_inv = None, None  ##Initialize.
    if ip_key == "origin":
        pred_normed = dataset_normed
    if ip_key == "ann":
        pred_normed = ANN.predict(cp.deepcopy(dataset_normed))
    if ip_key == "linear" or ip_key == "cubic":
        pred_normed = interpolate(dataset_normed, LP.input_size, LP.output_size, ip_key)

    pred_inv = Norm.inv_run(pred_normed)
    interp_normed[ip_key] = pred_normed
    interp_inv[ip_key] = pred_inv
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-fcb703ba1f1d> in <module>
#       6         pred_normed = dataset_normed
#       7     if ip_key == "ann":
# ----> 8         pred_normed = ANN.predict(cp.deepcopy(dataset_normed))
#       9     if ip_key == "linear" or ip_key == "cubic":
#      10         pred_normed = interpolate(dataset_normed, LP.input_size, LP.output_size, ip_key)
#
# ~/master/research/artificial_neural_network_gpu.py in predict(self, dataset, RMT_flag)
#      90             prediction[m_key] = cupy.asnumpy(prediction[m_key])
#      91         if RMT_flag:
# ---> 92             for m_key in m_list:
#      93                 prediction[m_key] = RMT[m_key].restore_mergertree(prediction[m_key])
#      94         return prediction
#
# ~/master/research/reshape_merger_tree.py in restore_mergertree(self, array_output)
#      64             end = restore_input[-1, self.input_size:]
#      65
# ---> 66             restore_array = np.concatenate([restore_input[:, 0:self.input_size], restore_output], axis = 1).reshape(-1)
#      67             restore_array = np.concatenate([self.surplus_list[idx], restore_array, end])
#      68             restore_list.append(restore_array)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# cupy/core/core.pyx in cupy.core.core.ndarray.__array_function__()
#
# ~/anaconda3/lib/python3.8/site-packages/cupy/_manipulation/join.py in concatenate(tup, axis, out)
#      55         tup = [m.ravel() for m in tup]
#      56         axis = 0
# ---> 57     return core.concatenate_method(tup, axis, out)
#      58
#      59
#
# cupy/core/_routines_manipulation.pyx in cupy.core._routines_manipulation.concatenate_method()
#
# cupy/core/_routines_manipulation.pyx in cupy.core._routines_manipulation.concatenate_method()
#
# TypeError: Only cupy arrays can be concatenated

# %%
with open(save_dir + "interp_normed.pickle", mode = "wb") as f:
    pickle.dump(interp_normed, f)
with open(save_dir + "interp_inv.pickle", mode = "wb") as f:
    pickle.dump(interp_inv, f)

# %%
scale_factor = make_dataset(mainbranch_list, "ScaleFactor", host_param, param, LP.extract_dataset, acc_sf)
with open(save_dir + "scale_factor.pickle", mode = "wb") as f:
    pickle.dump(scale_factor, f)

# %%
about_dir(save_dir, mainbranch_list, dir_list[dir_num], LP)

# %% [markdown]
# with open("directory_list.txt", mode = "a") as f:
#     f.writelines(save_dir + "\n")
